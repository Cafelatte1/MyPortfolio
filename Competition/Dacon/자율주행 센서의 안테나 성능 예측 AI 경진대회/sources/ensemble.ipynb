# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = "/content/drive/MyDrive/Colab Notebooks/projects/Dacon/LG_selfdriving_antenna_performance_prediction/"

# %%
submission = pd.read_csv(folder_path + "rawdata/sample_submission.csv")

# %%
submission.iloc[:, 1:] = np.concatenate([pd.read_csv(folder_path + "ensemble/" + i).iloc[:,1:].to_numpy()[np.newaxis, ...] for i in os.listdir(folder_path + "ensemble")], axis=0).mean(axis=0)

# %%
submission.head()
# Out:
#            ID      Y_01      Y_02      Y_03       Y_04       Y_05       Y_06  \
# 0  TEST_00001  1.462291  1.255909  0.926100  11.007445  25.074572  13.409077
# 1  TEST_00002  1.485751  1.233959  0.919201  10.624991  24.543183  13.229134
# 2  TEST_00003  1.464090  1.163545  0.885861  11.448977  25.580387  13.408544
# 3  TEST_00004  1.429619  1.152254  0.829685  11.978092  26.224492  13.603311
# 4  TEST_00005  1.350573  1.003348  0.758716  12.033556  25.325411  13.502320
#
#        Y_07       Y_08       Y_09       Y_10       Y_11       Y_12       Y_13  \
# 0  2.550864 -20.851769 -20.875210 -17.756995  19.691932 -20.807471 -20.808665
# 1  2.527592 -20.938851 -20.964485 -17.860728  19.398323 -20.874705 -20.912175
# 2  2.530300 -20.856297 -20.822194 -17.650712  19.651081 -20.713140 -20.800594
# 3  2.447207 -20.522499 -20.510574 -17.371356  19.990923 -20.469107 -20.512125
# 4  2.504856 -20.571089 -20.627321 -17.529912  19.790417 -20.512543 -20.563552
#
#         Y_14
# 0 -20.818864
# ...

# %%
submission.to_csv(folder_path + "ensemble/top5.csv", index=False)
