# %% [markdown]
# ## Setup
# * 제약 조건
#     * 이미지의 배치 순서는 정해져 있다 (제거)
# * using generic algorithm

# %%
GLOBAL_SEED = 42

import os
os.environ['PYTHONHASHSEED'] = str(GLOBAL_SEED)

import numpy as np # linear algebra
from numpy import random as np_rnd
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm import tqdm
import random as rnd
import pickle
import gc
import time
import string
from itertools import product, permutations

import torch
from torchvision import transforms
from PIL import Image
from torchvision.transforms import functional as tvf
from skimage.feature import hog, local_binary_pattern
import cv2

import optuna
from optuna import Trial, create_study
from optuna.samplers import TPESampler, RandomSampler, QMCSampler, BruteForceSampler, NSGAIISampler
import operator

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define helper functions

# %%
def seed_everything(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    # python random
    rnd.seed(seed)
    # numpy random
    np_rnd.seed(seed)
    # RAPIDS random
    try:
        cupy.random.seed(seed)
    except:
        pass
    # tf random
    try:
        tf_rnd.set_seed(seed)
    except:
        pass
    # pytorch random
    try:
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    except:
        pass

def pickleIO(obj, src, op="r"):
    if op=="w":
        with open(src, op + "b") as f:
            pickle.dump(obj, f)
    elif op=="r":
        with open(src, op + "b") as f:
            tmp = pickle.load(f)
        return tmp
    else:
        print("unknown operation")
        return obj
    
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

def findIdx(data_x, col_names):
    return [int(i) for i, j in enumerate(data_x) if j in col_names]

def diff(first, second):
    second = set(second)
    return [item for item in first if item not in second]

# %%
class CFG:
    debug = False
    image_root_path = "./data/"
    # h, w
    target_grid = (2, 2)
    operations = {
        "mirroring": lambda x: tvf.hflip(x),
        "flipping": lambda x: tvf.vflip(x),
        "rotation": lambda x: tvf.rotate(x, 90, expand=True)[:, :x.shape[2], :x.shape[1]],
    }
    inverse_operations = {
        "mirroring": lambda x: tvf.hflip(x),
        "flipping": lambda x: tvf.vflip(x),
        "rotation": lambda x: tvf.rotate(x, -90, expand=True)[:, :x.shape[2], :x.shape[1]],
    }
    shuffled_image_name_length = 4
    max_loss_value = 1000.0

# %% [markdown]
# ## Loading data

# %%
image_name = "the_last_supper.jpg"
shuffled_image_root_path = CFG.image_root_path + "random_" + image_name.split(".")[0] + "/"
createFolder(shuffled_image_root_path)

# %%
# 이미지 파일 경로
image_path = CFG.image_root_path + image_name
# 이미지 불러오기
image = Image.open(image_path)
# 이미지를 PyTorch Tensor로 변환
image = transforms.ToTensor()(image)
c, h, w = image.shape
c, h, w
# Out:
# (3, 551, 800)

# %% [markdown]
# ## Split & Apply random operations

# %%
operation_order = list(permutations(CFG.operations.keys()))
seed_everything()
selected_order = operation_order[rnd.randint(0, len(operation_order) - 1)]

# %%
# def do_random_operation(image, debug=False):
#     if debug:
#         seed_everything()
#     x = image.clone()
#     if rnd.random() > 0.5:
#         for op in selected_order:
#             x = CFG.operations[op](x)
#     return x

# # 이미지별 모든 연산 일괄적으로 적용
# def do_random_operation(image, debug=False):
#     if debug:
#         seed_everything()
#     x = image.clone()
#     if rnd.random() > 0.5:
#         for op in selected_order:
#             x = CFG.operations[op](x)
#     return x

# 이미지별 모든 연산 독립적으로 적용
def do_random_operation(image, debug=False):
    if debug:
        seed_everything()
    x = image.clone()
    for op in operation_order[rnd.randint(0, len(operation_order) - 1)]:
        if rnd.random() > 0.5:
            x = CFG.operations[op](x)
    return x


# 무작위로 이름을 생성하는 함수
def generate_random_name(length, seed=42):
    rnd.seed(seed)
    # 대소문자 알파벳과 숫자로 이루어진 문자열을 생성
    characters = string.ascii_letters + string.digits
    # 무작위로 길이가 `length`인 문자열 생성
    random_name = ''.join(rnd.choice(characters) for _ in range(length))
    return random_name

# %%
grid_h, grid_w = h // CFG.target_grid[0], w // CFG.target_grid[1]
grid_h, grid_w
# Out:
# (275, 400)

# %%
for fpath in os.listdir(shuffled_image_root_path):
    os.remove(shuffled_image_root_path + fpath)

seed_cnt = 0
for idx_h in range(CFG.target_grid[0]):
    for idx_w in range(CFG.target_grid[1]):
        seed_everything(seed_cnt)
        cropped_image = image[:, (idx_h * grid_h):((idx_h+1) * grid_h), (idx_w * grid_w):((idx_w+1) * grid_w)]
        cropped_image = do_random_operation(cropped_image, debug=CFG.debug)
        cropped_image = transforms.ToPILImage()(cropped_image)
        cropped_image.save(shuffled_image_root_path + f"{generate_random_name(CFG.shuffled_image_name_length, seed=seed_cnt)}.jpg")
        # cropped_image.save(shuffled_image_root_path + f"{str(seed_cnt).zfill(CFG.shuffled_image_name_length)}.jpg")
        seed_cnt += 1
        # break

# %% [markdown]
# ## Re-construction

# %% [markdown]
# ### Loading sub-images

# %%
image_container = [transforms.ToTensor()(Image.open(shuffled_image_root_path + i)) for i in sorted(os.listdir(shuffled_image_root_path))]
len(image_container)
# Out:
# 4

# %%
resolution_metainfo = []
for idx, value in enumerate(image_container):
    resolution_metainfo.append({
        "idx": idx,
        "h": value.shape[1],
        "w": value.shape[2],
    })
resolution_metainfo = pd.DataFrame(resolution_metainfo)
print(resolution_metainfo)
resolution_range = tuple(set(resolution_metainfo["h"].to_list() + resolution_metainfo["w"].to_list()))
# resolution range must be less than 3
assert len(resolution_range) <= 2
print(resolution_range)
# Out:
#    idx    h    w
# 0    0  275  400
# 1    1  275  400
# 2    2  400  275
# 3    3  275  400
# (400, 275)

# %%
hog_params = {
    "orientations": 9,
    "cells_per_block": (3, 3),
    "pixels_per_cell": (3, 3),
    "channel_axis": 0,
}
lbp_params = {
    "P": 3 * 3,
    "R": 3,
    "method": "uniform",
}

def get_pixel_histogram_feature_vector(x, n_bins=64):
    output = []
    for i in x:
        histogram, _ = torch.histogram(i, bins=n_bins, range=(0, 1))
        # normalizing by channels
        output.append(histogram / histogram.sum())
    return torch.cat(output, dim=-1)

def get_hog_feature_vector(x):
    return torch.from_numpy(hog(x.detach().cpu().numpy(), **hog_params).flatten())

def get_lbp_feature_vector(x):
    return torch.from_numpy(local_binary_pattern(tvf.rgb_to_grayscale(x).squeeze(dim=0).detach().cpu().numpy(), **lbp_params).flatten())

def get_pixel_variety(x1, x2, n_bins=64):
    pixel_variety = torch.stack([torch.histogram(i, bins=n_bins, range=(0, 1))[0] for i in x1]) + torch.stack([torch.histogram(i, bins=n_bins, range=(0, 1))[0] for i in x2])
    return 1 / (pixel_variety.flatten().std().item() + 1.0)

def get_local_blended_score(x1, x2):
    score = [
        torch.sqrt(torch.pow(x1.flatten() - x2.flatten(), 2).mean()).item() / 3.0 * 1.5,
        torch.sqrt(torch.pow(get_pixel_histogram_feature_vector(x1) - get_pixel_histogram_feature_vector(x2), 2).mean()).item() * 20.0,
        torch.sqrt(torch.pow(get_hog_feature_vector(x1) - get_hog_feature_vector(x2), 2).mean()).item(),
        torch.sqrt(torch.pow(get_lbp_feature_vector(x1) - get_lbp_feature_vector(x2), 2).mean()).item() / 100.0,
        get_pixel_variety(x1, x2),
    ]
    # score = [
    #     torch.sqrt(torch.pow(x1.flatten() - x2.flatten(), 2).mean()).item(),
    #     torch.sqrt(torch.pow(get_pixel_histogram_feature_vector(x1) - get_pixel_histogram_feature_vector(x2), 2).mean()).item(),
    #     torch.sqrt(torch.pow(get_hog_feature_vector(x1) - get_hog_feature_vector(x2), 2).mean()).item(),
    #     torch.sqrt(torch.pow(get_lbp_feature_vector(x1) - get_lbp_feature_vector(x2), 2).mean()).item(),
    # ]
    # print(score)
    return np.mean(score)
    # return np.mean(np.log1p(score))

def get_consistency_score(x, order):
    if isinstance(x, list):
        x = torch.stack(x, dim=0)

    rows_global = []
    rows_local_binary = []
    rows_local_lbp = []
    row_idx = np.array([int(np.floor(order[i] / (CFG.target_grid[1]))) for i in range(len(x))])
    for i in range(CFG.target_grid[0]):
        row_image = x[row_idx == i]
        row_order = order[row_idx == i]

        rows_global.append(torch.cat([j for j in row_image[np.argsort(row_order)]], dim=-1))
        rows_local_binary.append(torch.cat([torch.from_numpy(cv2.threshold(np.array(transforms.ToPILImage()(tvf.rgb_to_grayscale(j).squeeze(dim=0))), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]) for j in row_image[np.argsort(row_order)]], dim=-1))
        rows_local_lbp.append(torch.cat([torch.from_numpy(local_binary_pattern(tvf.rgb_to_grayscale(j).squeeze(dim=0).detach().cpu().numpy(), **lbp_params).flatten()) for j in row_image[np.argsort(row_order)]], dim=-1))

    rows_global = torch.cat(rows_global, dim=1)
    rows_global_binary = torch.from_numpy(cv2.threshold(np.array(transforms.ToPILImage()(tvf.rgb_to_grayscale(rows_global).squeeze(dim=0))), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]).to(torch.float32)
    rows_global_lbp = torch.from_numpy(local_binary_pattern(tvf.rgb_to_grayscale(rows_global).squeeze(dim=0).detach().cpu().numpy(), **lbp_params).flatten()).to(torch.float32)
    rows_local_binary = torch.cat(rows_local_binary, dim=0).to(torch.float32)
    rows_local_lbp = torch.cat(rows_local_lbp, dim=0).to(torch.float32)

    output = [
        {"thresholding_consistency": torch.sqrt(torch.pow(rows_global_binary - rows_local_binary, 2).mean()).item() / 200.0},
        {"lbp_consistency": torch.sqrt(torch.pow(rows_global_lbp - rows_local_lbp, 2).mean()).item() / 25.0},
    ]
    # score = [
    #     torch.sqrt(torch.pow(rows_global_binary - rows_local_binary, 2).mean()).item(),
    #     torch.sqrt(torch.pow(rows_global_lbp - rows_local_lbp, 2).mean()).item(),
    # ]
    return output
    # return np.mean(np.log1p(score))

# %%
# position_order = [3, 0, 1, 2]
# min_edge_pixels = 9
# ratio = 0.05
# transformed_image = [i.clone() for i in image_container]
# for i in range(len(transformed_image)):
#     if transformed_image[i].shape[1] != 252:
#         transformed_image[i] = CFG.inverse_operations["rotation"](transformed_image[i])
#     print(transformed_image[i].shape)

# %%
# score = []
# for pos in position_order:
#     break
#     # check height upper
#     if (pos + (CFG.target_grid[1] * -1)) >= 0:
#         target_image = transformed_image[position_order.index(pos + (CFG.target_grid[1] * -1))]
#         pos_image = transformed_image[pos]
#         # if shape is not matched, return large loss value
#         if target_image.shape[2] != pos_image.shape[2]:
#             score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * -1))])): CFG.max_loss_value})
#         else:
#             # for target image
#             target_image = target_image[:, (-1 * max(min_edge_pixels, int(target_image.shape[1] * ratio))):, :]
            
#             # for present image
#             pos_image = pos_image[:, :(1 * max(min_edge_pixels, int(pos_image.shape[1] * ratio))):, :]

#             target_image = tvf.vflip(target_image)
#             # get l2 distance from feature vector
#             target_image = tvf.vflip(target_image)
#             score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * -1))])): get_local_blended_score(target_image, pos_image)})
            

#     # check height lower
#     if (pos + (CFG.target_grid[1] * 1)) <= (CFG.target_grid[0] * CFG.target_grid[1] - 1):
#         target_image = transformed_image[(pos + (CFG.target_grid[1] * 1))]
#         pos_image = transformed_image[pos]
#         # if shape is not matched, return large loss value
#         if target_image.shape[2] != pos_image.shape[2]:
#             score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * 1))])): CFG.max_loss_value})
#         else:                
#             # for target image
#             target_image = target_image[:, :(1 * max(min_edge_pixels, int(target_image.shape[1] * ratio))), :]
#             target_image = tvf.vflip(target_image)
#             # for present image
#             pos_image = pos_image[:, (-1 * max(min_edge_pixels, int(pos_image.shape[1] * ratio))):, :]
#             # get l2 distance from feature vector
#             score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * 1))])): get_local_blended_score(target_image, pos_image)})
        
#     # check width left
#     if int(np.floor((pos - 1) / CFG.target_grid[1])) == int(np.floor(pos / CFG.target_grid[1])):
#         # print(44)
#         target_image = transformed_image[pos - 1]
#         pos_image = transformed_image[pos]
#         # if shape is not matched, return large loss value
#         if target_image.shape[1] != pos_image.shape[1]:
#             # print(33)
#             score.append({tuple(sorted([pos, (pos - 1)])): CFG.max_loss_value})
#             # print(score)
#         else:                
#             # for target image
#             target_image = target_image[:, :, (-1 * max(min_edge_pixels, int(target_image.shape[2] * ratio))):]
#             target_image = tvf.hflip(target_image)
#             # for present image
#             pos_image = pos_image[:, :, :(1 * max(min_edge_pixels, int(pos_image.shape[2] * ratio)))]
#             # get l2 distance from feature vector
#             score.append({tuple(sorted([pos, (pos - 1)])): get_local_blended_score(target_image, pos_image)})

#     # check width right
#     if int(np.floor((pos + 1) / CFG.target_grid[1])) == int(np.floor(pos / CFG.target_grid[1])):
#         target_image = transformed_image[pos + 1]
#         pos_image = transformed_image[pos]
#         # if shape is not matched, return large loss value
#         if target_image.shape[1] != pos_image.shape[1]:
#             score.append({tuple(sorted([pos, (pos + 1)])): CFG.max_loss_value})
#         else:                
#             # for target image
#             target_image = target_image[:, :, :(1 * max(min_edge_pixels, int(target_image.shape[2] * ratio)))]
#             target_image = tvf.hflip(target_image)
#             # for present image
#             pos_image = pos_image[:, :, (-1 * max(min_edge_pixels, int(pos_image.shape[2] * ratio))):]
#             # get l2 distance from feature vector
#             score.append({tuple(sorted([pos, (pos + 1)])): get_local_blended_score(target_image, pos_image)})
    
#     break

# %%
# V3
def get_edge_similarity_score(transformed_image, position_order, ratio=0.05, min_edge_pixels=9, consistency_score_weight="local_size"):
    score = []
    for pos in position_order:

        # check height upper
        if (pos + (CFG.target_grid[1] * -1)) >= 0:
            target_image = transformed_image[position_order.index(pos + (CFG.target_grid[1] * -1))]
            pos_image = transformed_image[position_order.index(pos)]
            # if shape is not matched, return large loss value
            if target_image.shape[2] != pos_image.shape[2]:
                score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * -1))])): CFG.max_loss_value})
            else:
                # for target image
                target_image = target_image[:, (-1 * max(min_edge_pixels, int(target_image.shape[1] * ratio))):, :]
                
                # for present image
                pos_image = pos_image[:, :(1 * max(min_edge_pixels, int(pos_image.shape[1] * ratio))):, :]

                target_image = tvf.vflip(target_image)
                # get l2 distance from feature vector
                target_image = tvf.vflip(target_image)
                score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * -1))])): get_local_blended_score(target_image, pos_image)})
                

        # check height lower
        if (pos + (CFG.target_grid[1] * 1)) <= (CFG.target_grid[0] * CFG.target_grid[1] - 1):
            target_image = transformed_image[position_order.index(pos + (CFG.target_grid[1] * 1))]
            pos_image = transformed_image[position_order.index(pos)]
            # if shape is not matched, return large loss value
            if target_image.shape[2] != pos_image.shape[2]:
                score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * 1))])): CFG.max_loss_value})
            else:                
                # for target image
                target_image = target_image[:, :(1 * max(min_edge_pixels, int(target_image.shape[1] * ratio))), :]
                target_image = tvf.vflip(target_image)
                # for present image
                pos_image = pos_image[:, (-1 * max(min_edge_pixels, int(pos_image.shape[1] * ratio))):, :]
                # get l2 distance from feature vector
                score.append({tuple(sorted([pos, (pos + (CFG.target_grid[1] * 1))])): get_local_blended_score(target_image, pos_image)})
            
        # check width left
        if int(np.floor((pos - 1) / CFG.target_grid[1])) == int(np.floor(pos / CFG.target_grid[1])):
            # print(44)
            target_image = transformed_image[position_order.index(pos - 1)]
            pos_image = transformed_image[position_order.index(pos)]
            # if shape is not matched, return large loss value
            if target_image.shape[1] != pos_image.shape[1]:
                # print(33)
                score.append({tuple(sorted([pos, (pos - 1)])): CFG.max_loss_value})
                # print(score)
            else:                
                # for target image
                target_image = target_image[:, :, (-1 * max(min_edge_pixels, int(target_image.shape[2] * ratio))):]
                target_image = tvf.hflip(target_image)
                # for present image
                pos_image = pos_image[:, :, :(1 * max(min_edge_pixels, int(pos_image.shape[2] * ratio)))]
                # get l2 distance from feature vector
                score.append({tuple(sorted([pos, (pos - 1)])): get_local_blended_score(target_image, pos_image)})

        # check width right
        if int(np.floor((pos + 1) / CFG.target_grid[1])) == int(np.floor(pos / CFG.target_grid[1])):
            target_image = transformed_image[position_order.index(pos + 1)]
            pos_image = transformed_image[position_order.index(pos)]
            # if shape is not matched, return large loss value
            if target_image.shape[1] != pos_image.shape[1]:
                score.append({tuple(sorted([pos, (pos + 1)])): CFG.max_loss_value})
            else:                
                # for target image
                target_image = target_image[:, :, :(1 * max(min_edge_pixels, int(target_image.shape[2] * ratio)))]
                target_image = tvf.hflip(target_image)
                # for present image
                pos_image = pos_image[:, :, (-1 * max(min_edge_pixels, int(pos_image.shape[2] * ratio))):]
                # get l2 distance from feature vector
                score.append({tuple(sorted([pos, (pos + 1)])): get_local_blended_score(target_image, pos_image)})

    # df_score = pd.Series([list(i.values())[0] for i in score], index=[list(i.keys())[0] for i in score])
    # df_score.index.name = "pair"
    # df_score = df_score.groupby("pair").mean()

    # local_score = df_score.mean()
    # global_score = get_consistency_score(transformed_image, position_order) * (consistency_score_weight if isinstance(consistency_score_weight, float) else (1 / len(transformed_image)))
    # # print(local_score, global_score)
    # return local_score + global_score

    score.extend(get_consistency_score(transformed_image, np.array(position_order)))
    
    df_score = pd.Series([list(i.values())[0] for i in score], index=[list(i.keys())[0] for i in score])
    # print(df_score)
    df_score.index.name = "pair"
    df_score = df_score.groupby("pair").mean()

    return df_score.mean()

# %%
inverse_operation_order = list(permutations(CFG.inverse_operations.keys()))

# optuna function
def optuna_objective_function(trial: Trial, output_container):

    transformed_image = [i.clone() for i in image_container]
    
    # set searching parameters
    tuner_params = {}
    for i in range(len(transformed_image)):
        tuner_params[f"img{i}_opSeq"] = trial.suggest_categorical(f"img{i}_opSeq", list(range(len(inverse_operation_order))))
        for op in CFG.inverse_operations.keys():
            if op != "rotation":
                tuner_params[f"img{i}_{op}"] = trial.suggest_categorical(f"img{i}_{op}", [0, 1])
        tuner_params[f"img{i}_rank"] = trial.suggest_float(f"img{i}_rank", 0.0, 1.0)
    # set resolution indicating paramter for reducing complexity
    tuner_params["resolution_h"] = trial.suggest_categorical(f"resolution_h", resolution_range)

    # transform images with seaching params & assign order
    # first, align all images with selected resolution
    for i in range(len(transformed_image)):
        for op in inverse_operation_order[tuner_params[f"img{i}_opSeq"]]:
            if op != "rotation":
                if tuner_params[f"img{i}_{op}"] == 1:
                    transformed_image[i] = CFG.inverse_operations[op](transformed_image[i])
            else:
                if transformed_image[i].shape[1] != tuner_params["resolution_h"]:
                    transformed_image[i] = CFG.inverse_operations["rotation"](transformed_image[i])

    # assign postion on images
    position_order = list(np.argsort([tuner_params[f"img{i}_rank"] for i in range(len(transformed_image))]))
    # position_order = np.array(range(len(transformed_image)))

    # calcuate edge similarity score
    optuna_score = get_edge_similarity_score(transformed_image, position_order)
    
    if optuna_score < output_container["optuna_score"]:
        output_container["optuna_score"] = optuna_score
        print(f"Found best at {trial.number} trial (Score -> {optuna_score})")

    return optuna_score

class Optuna_EarlyStoppingCallback(object):
    """Early stopping callback for Optuna."""

    def __init__(self, early_stopping_rounds: int, direction: str = "minimize") -> None:
        self.early_stopping_rounds = early_stopping_rounds

        self._iter = 0

        if direction == "minimize":
            self._operator = operator.lt
            self._score = np.inf
        elif direction == "maximize":
            self._operator = operator.gt
            self._score = -np.inf
        else:
            ValueError(f"invalid direction: {direction}")

    def __call__(self, study: optuna.Study, trial: optuna.Trial) -> None:
        """Do early stopping."""
        if self._operator(study.best_value, self._score):
            self._iter = 0
            self._score = study.best_value
        else:
            self._iter += 1

        if self._iter >= self.early_stopping_rounds:
            study.stop()

# %% [markdown]
# ### Optimization

# %%
def do_optimization(seed):
    generic_sampler_params = {
        "population_size": 50,
        "mutation_prob": 0.05,
        "crossover_prob": 0.8,
        "swapping_prob": 0.5,
        "seed": seed,
    }

    output_container = {"optuna_score": np.inf}
    optuna_direction = "minimize"
    optuna_trials = 10_000
    optuna_earlyStopping = Optuna_EarlyStoppingCallback(max(1, int(optuna_trials * 0.2)), direction=optuna_direction)

    optuna_timout = 6 * 3600
    optuna_study = create_study(direction=optuna_direction, sampler=NSGAIISampler(**generic_sampler_params))

    optuna_study.optimize(
        lambda trial: optuna_objective_function(
            trial, output_container,
        ),
        n_jobs=-1, n_trials=optuna_trials, timeout=optuna_timout, callbacks=[optuna_earlyStopping]
    )
    
    return optuna_study.best_params

# %%
# %%time

try_seed = 1

seed_everything(try_seed)

best_params = do_optimization(try_seed)
# Out:
# [I 2023-09-10 15:13:59,383] A new study created in memory with name: no-name-6a1c655e-de31-4650-bc6b-145679b4c2ef
# [I 2023-09-10 15:14:02,208] Trial 9 finished with value: 0.19143117071076246 and parameters: {'img0_opSeq': 2, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.7046101475690326, 'img1_opSeq': 1, 'img1_mirroring': 0, 'img1_flipping': 0, 'img1_rank': 0.5557188149304936, 'img2_opSeq': 4, 'img2_mirroring': 0, 'img2_flipping': 0, 'img2_rank': 0.8918631092007088, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.6807956182799112, 'resolution_h': 275}. Best is trial 9 with value: 0.19143117071076246.
# [I 2023-09-10 15:14:02,209] Trial 2 finished with value: 0.20929616369922277 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 1, 'img0_rank': 0.4832858143680423, 'img1_opSeq': 3, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.5551010417357631, 'img2_opSeq': 5, 'img2_mirroring': 0, 'img2_flipping': 0, 'img2_rank': 0.8326222075890214, 'img3_opSeq': 3, 'img3_mirroring': 1, 'img3_flipping': 0, 'img3_rank': 0.41438909993406725, 'resolution_h': 275}. Best is trial 9 with value: 0.19143117071076246.
# [I 2023-09-10 15:14:02,228] Trial 8 finished with value: 0.21935999776940615 and parameters: {'img0_opSeq': 2, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.40200636932654077, 'img1_opSeq': 5, 'img1_mirroring': 0, 'img1_flipping': 0, 'img1_rank': 0.5514199702068865, 'img2_opSeq': 5, 'img2_mirroring': 0, 'img2_flipping': 0, 'img2_rank': 0.5837626134897668, 'img3_opSeq': 2, 'img3_mirroring': 0, 'img3_flipping': 1, 'img3_rank': 0.7299400073730882, 'resolution_h': 275}. Best is trial 9 with value: 0.19143117071076246.
# [I 2023-09-10 15:14:02,310] Trial 11 finished with value: 0.19120197733929753 and parameters: {'img0_opSeq': 2, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.13861377053626878, 'img1_opSeq': 1, 'img1_mirroring': 0, 'img1_flipping': 1, 'img1_rank': 0.8935270559268957, 'img2_opSeq': 0, 'img2_mirroring': 0, 'img2_flipping': 0, 'img2_rank': 0.08414563190185931, 'img3_opSeq': 3, 'img3_mirroring': 1, 'img3_flipping': 0, 'img3_rank': 0.6278394392272083, 'resolution_h': 275}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,327] Trial 10 finished with value: 0.19537396927201148 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 1, 'img0_rank': 0.6933825459789271, 'img1_opSeq': 4, 'img1_mirroring': 0, 'img1_flipping': 0, 'img1_rank': 0.320114339187783, 'img2_opSeq': 5, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5421504570137212, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.6963019298722911, 'resolution_h': 275}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,371] Trial 1 finished with value: 0.198702173105712 and parameters: {'img0_opSeq': 1, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.03767054497642375, 'img1_opSeq': 4, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.6346782744934366, 'img2_opSeq': 0, 'img2_mirroring': 1, 'img2_flipping': 1, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 3, 'img3_mirroring': 0, 'img3_flipping': 1, 'img3_rank': 0.5741402807022494, 'resolution_h': 400}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,373] Trial 5 finished with value: 0.21306454285615758 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.6689438237109726, 'img1_opSeq': 3, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.27532777706042644, 'img2_opSeq': 2, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.35745310406235753, 'img3_opSeq': 2, 'img3_mirroring': 1, 'img3_flipping': 0, 'img3_rank': 0.33873593378633915, 'resolution_h': 400}. Best is trial 11 with value: 0.19120197733929753.
# Found best at 9 trial (Score -> 0.19143117071076246)
# Found best at 11 trial (Score -> 0.19120197733929753)
# [I 2023-09-10 15:14:02,374] Trial 4 finished with value: 0.2024302799386745 and parameters: {'img0_opSeq': 1, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.07537204624259253, 'img1_opSeq': 3, 'img1_mirroring': 0, 'img1_flipping': 1, 'img1_rank': 0.6192220224454722, 'img2_opSeq': 2, 'img2_mirroring': 1, 'img2_flipping': 1, 'img2_rank': 0.7547122157362729, 'img3_opSeq': 4, 'img3_mirroring': 1, 'img3_flipping': 0, 'img3_rank': 0.20522782948642082, 'resolution_h': 275}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,378] Trial 0 finished with value: 0.2211454745081054 and parameters: {'img0_opSeq': 5, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.02581397470375635, 'img1_opSeq': 1, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.7101329704944208, 'img2_opSeq': 5, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.6393606282934118, 'img3_opSeq': 2, 'img3_mirroring': 0, 'img3_flipping': 1, 'img3_rank': 0.005725833521190937, 'resolution_h': 400}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,381] Trial 13 finished with value: 0.2222141819369611 and parameters: {'img0_opSeq': 1, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.44034718327030753, 'img1_opSeq': 5, 'img1_mirroring': 0, 'img1_flipping': 1, 'img1_rank': 0.9768981967928058, 'img2_opSeq': 3, 'img2_mirroring': 0, 'img2_flipping': 0, 'img2_rank': 0.523063716407887, 'img3_opSeq': 5, 'img3_mirroring': 1, 'img3_flipping': 1, 'img3_rank': 0.7248924489629525, 'resolution_h': 275}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,438] Trial 3 finished with value: 0.21544417069255983 and parameters: {'img0_opSeq': 1, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.8582630181542592, 'img1_opSeq': 4, 'img1_mirroring': 0, 'img1_flipping': 0, 'img1_rank': 0.5638050588148245, 'img2_opSeq': 0, 'img2_mirroring': 0, 'img2_flipping': 1, 'img2_rank': 0.7683505321560073, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.6914832137605432, 'resolution_h': 400}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,442] Trial 14 finished with value: 0.1947672647011602 and parameters: {'img0_opSeq': 2, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.9029332966699334, 'img1_opSeq': 4, 'img1_mirroring': 0, 'img1_flipping': 0, 'img1_rank': 0.22165717277775054, 'img2_opSeq': 2, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.06575442530691333, 'img3_opSeq': 0, 'img3_mirroring': 0, 'img3_flipping': 1, 'img3_rank': 0.9972743506914079, 'resolution_h': 400}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,458] Trial 7 finished with value: 0.2124420609348002 and parameters: {'img0_opSeq': 3, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.18011448137339903, 'img1_opSeq': 4, 'img1_mirroring': 1, 'img1_flipping': 0, 'img1_rank': 0.6150852508998481, 'img2_opSeq': 2, 'img2_mirroring': 0, 'img2_flipping': 1, 'img2_rank': 0.33204476979539677, 'img3_opSeq': 1, 'img3_mirroring': 1, 'img3_flipping': 0, 'img3_rank': 0.7927757180199019, 'resolution_h': 400}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,470] Trial 6 finished with value: 0.21102735953645282 and parameters: {'img0_opSeq': 4, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.12412827659786174, 'img1_opSeq': 4, 'img1_mirroring': 0, 'img1_flipping': 1, 'img1_rank': 0.5717516939132448, 'img2_opSeq': 3, 'img2_mirroring': 1, 'img2_flipping': 1, 'img2_rank': 0.7031564009147033, 'img3_opSeq': 1, 'img3_mirroring': 1, 'img3_flipping': 0, 'img3_rank': 0.4221424443793478, 'resolution_h': 400}. Best is trial 11 with value: 0.19120197733929753.
# [I 2023-09-10 15:14:02,473] Trial 12 finished with value: 0.2162639798332612 and parameters: {'img0_opSeq': 3, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0
and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 1, 'img0_rank': 0.12412827659786174, 'img1_opSeq': 3, 'img1_mirroring': 0, 'img1_flipping': 0, 'img1_rank': 0.31520311391879074, 'img2_opSeq': 4, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.8764320710102482, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 1, 'img3_rank': 0.4221424443793478, 'resolution_h': 400}. Best is trial 24 with value: 0.17058333805302403.
# [I 2023-09-10 15:14:17,804] Trial 88 finished with value: 0.1952342332723586 and parameters: {'img0_opSeq': 2, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.015505945435377755, 'img1_opSeq': 5, 'img1_mirroring': 0, 'img1_flipping': 0, 'img1_rank': 0.40856459828890035, 'img2_opSeq': 4, 'img2_mirroring': 0, 'img2_flipping': 1, 'img2_rank': 0.03925723377306667, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.22034325739241567, 'resolution_h': 275}. Best is trial 24 with value: 0.17058333805302403.
# [I 2023-09-10 15:14:17,816] Trial 86 finished with value: 0.20106528175273883 and parameters: {'img0_opSeq': 1, 'img0_mirroring': 0, 'img0_flipping': 1, 'img0_rank': 0.04632145921072672, 'img1_opSeq': 3, 'img1_mirroring': 0, 'img1_flipping': 1, 'img1_rank': 0.5557188149304936, 'img2_opSeq': 4, 'img2_mirroring': 1, 'img2_flipping': 1, 'img2_rank': 0.8918631092007088, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.20522782948642082, 'resolution_h': 275}. Best is trial 24 with value: 0.17058333805302403.
# ...
# [I 2023-09-10 15:22:00,358] Trial 2544 finished with value: 0.22099961402062326 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 1, 'img0_rank': 0.49292626390894456, 'img1_opSeq': 3, 'img1_mirroring': 0, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 5, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 1, 'img3_rank': 0.8488295467374989, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:00,372] Trial 2548 finished with value: 0.1766131857488812 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 0, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:00,416] Trial 2546 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:00,452] Trial 2547 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:01,988] Trial 2549 finished with value: 0.1770991364909964 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 1, 'img2_rank': 0.14996640658894056, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:02,756] Trial 2550 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 3, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,030] Trial 2551 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,225] Trial 2552 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,226] Trial 2554 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 3, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,227] Trial 2555 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,281] Trial 2560 finished with value: 0.1766131857488812 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 0, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,377] Trial 2561 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,397] Trial 2559 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,398] Trial 2562 finished with value: 0.1770991364909964 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 1, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,435] Trial 2557 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 3, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,444] Trial 2556 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,523] Trial 2563 finished with value: 0.21349310868153473 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.8111747430003834, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,524] Trial 2558 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,525] Trial 2564 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.48293743025538005, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:03,530] Trial 2553 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,043] Trial 2565 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 5, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,565] Trial 2566 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,871] Trial 2568 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.3522903782458572, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,881] Trial 2567 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.771670929171034, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,902] Trial 2573 finished with value: 0.1770991364909964 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 1, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,917] Trial 2569 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,929] Trial 2570 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.5550884020655381, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,946] Trial 2571 finished with value: 0.16320190270008297 and parameters: {'img0_opSeq': 0, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.8521379015572097, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 4, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 275}. Best is trial 559 with value: 0.16320190270008297.
# [I 2023-09-10 15:22:04,947] Trial 2572 finished with value: 0.21787007245138154 and parameters: {'img0_opSeq': 3, 'img0_mirroring': 1, 'img0_flipping': 0, 'img0_rank': 0.6025627800467425, 'img1_opSeq': 0, 'img1_mirroring': 1, 'img1_flipping': 1, 'img1_rank': 0.06027605357694166, 'img2_opSeq': 1, 'img2_mirroring': 1, 'img2_flipping': 0, 'img2_rank': 0.5810558635438268, 'img3_opSeq': 1, 'img3_mirroring': 0, 'img3_flipping': 0, 'img3_rank': 0.0003501571728148356, 'resolution_h': 400}. Best is trial 559 with value: 0.16320190270008297.
# CPU times: total: 1h 31min 14s
# Wall time: 8min 5s

# %% [markdown]
# ### Inference

# %%
transformed_image = [i.clone() for i in image_container]

# transform images with seaching params & assign order
# first, align all images with selected resolution
for i in range(len(transformed_image)):
    for op in inverse_operation_order[best_params[f"img{i}_opSeq"]]:
        if op != "rotation":
            if best_params[f"img{i}_{op}"] == 1:
                transformed_image[i] = CFG.inverse_operations[op](transformed_image[i])
        else:
            if transformed_image[i].shape[1] != best_params["resolution_h"]:
                transformed_image[i] = CFG.inverse_operations["rotation"](transformed_image[i])

position_order = np.argsort([best_params[f"img{i}_rank"] for i in range(len(transformed_image))])
transformed_image = torch.stack(transformed_image, dim=0)
transformed_image.shape
# Out:
# torch.Size([4, 3, 275, 400])

# %%
rows = []
# position_order = np.array(list(range(len(transformed_image))))
row_idx = np.array([int(np.floor(position_order[i] / (CFG.target_grid[1]))) for i in range(len(transformed_image))])
for i in range(CFG.target_grid[0]):
    row_image = transformed_image[row_idx == i]
    row_order = position_order[row_idx == i]
    rows.append(torch.cat([j for j in row_image[np.argsort(row_order)]], dim=-1))
    # break
final_image = torch.cat(rows, dim=1)

# %%
transforms.ToPILImage()(final_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x550>
