# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q -U datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 19.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 34.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.9 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 4.7 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for accelerate (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.6 MB/s eta 0:00:00

# %%
GLOBAL_SEED = 42

import os
os.environ['PYTHONHASHSEED'] = str(GLOBAL_SEED)

import pandas as pd
import numpy as np
from numpy import random as np_rnd
import random as rnd
import re
import os
import pickle
import shutil
from datetime import datetime
from time import time
import gc
from itertools import product
import json
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
import transformers
from transformers import get_polynomial_decay_schedule_with_warmup
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import EarlyStoppingCallback
from datasets import Dataset, DatasetDict
from torch.utils.data import DataLoader
from peft import prepare_model_for_kbit_training
from peft import LoraConfig
from peft import get_peft_model

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
def seed_everything(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    # python random
    rnd.seed(seed)
    # numpy random
    np_rnd.seed(seed)
    # RAPIDS random
    try:
        cupy.random.seed(seed)
    except:
        pass
    # tf random
    try:
        tf_rnd.set_seed(seed)
    except:
        pass
    # pytorch random
    try:
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    except:
        pass

def pickleIO(obj, src, op="r"):
    if op=="w":
        with open(src, op + "b") as f:
            pickle.dump(obj, f)
    elif op=="r":
        with open(src, op + "b") as f:
            tmp = pickle.load(f)
        return tmp
    else:
        print("unknown operation")
        return obj

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print('Error: Creating directory. ' + directory)

def findIdx(data_x, col_names):
    return [int(i) for i, j in enumerate(data_x) if j in col_names]

def diff(first, second):
    second = set(second)
    return [item for item in first if item not in second]

def get_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_params = 0
    for _, param in model.named_parameters():
        all_params += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    return {"all_param": all_params, "trainable_params": trainable_params, "trainable%": 100 * trainable_params / all_params}

# %%
class CFG:
    debug = False
    dataset_version = "5주차_v3"

    model_id = "nlpai-lab/kullm-polyglot-12.8b-v2"
    epochs = 2 if debug else 10
    early_stopping_rounds = 10
    batch_size = 1
    eta = 5e-4
    weight_decay = 1e-4
    # r: [16, 8, 4] about-> [20%, 10%, 5%]
    max_lora_r = 8
    max_seq_len = 256
    gen_max_seq_len = 192

    validation_split = False
    validation_ratio = 0.1

# %% [markdown]
# ## Loading data

# %%
df_qa = pd.read_csv(f"/content/drive/MyDrive/Colab Notebooks/dataset/prepdata/FNCSP_FAQ_전처리_{CFG.dataset_version}.csv", encoding="utf8")
df_qa.columns = ["input", "output"]
df_qa["input"] = df_qa["input"].astype("str").apply(lambda x: x.strip())
df_qa["output"] = df_qa["output"].astype("str").apply(lambda x: x.strip())
if CFG.debug:
    df_qa = df_qa.sample(n=50, random_state=42).reset_index(drop=True)
else:
    df_qa = df_qa.sample(frac=1, random_state=42).reset_index(drop=True)
df_qa
# Out:
#                                                   input  \
# 0                                          당좌자산이 무엇인가요?
# 1                         기술의 신뢰성 평가 시 어떤 접근 방식을 사용하나요?
# 2                 컨설턴트 구독 서비스를 중간에 해지하면, 요금이 어떻게 처리되나요?
# 3     데이터 몰에서 제공하는 샘플 데이터를 다운로드 받지 못하고 있다면 어떤 조치를 취해...
# 4                                    당좌 비율이 무엇인지 알려주세요.
# ...                                                 ...
# 3037             기업 정보 요약에서 등급을 선정하는 기준이 어떻게 되는지 알려주세요.
# 3038                        기업컨설팅보고서에서 설문 진행하는 표시가 안돼요.
# 3039              분석 결과에서 워드 클라우드의 글자 크기는 어떤 기준으로 정하나요?
# 3040                   마케팅 역량 지수에서 시장 가능성의 세부요인은 무엇인가요?
# 3041               어떤 신용카드가 결제에 사용될 수 있는지 정보를 알 수 있을까요?
#
#                                                  output
# 0     유동자산 중에서 판매과정을 거치지 않고 1년 이내에 현금화가 가능한 자산을 말합니다...
# 1                   해당 기술의 정확성과 구현 기술 내용의 충실 정도를 평가합니다.
# 2                중간 해지 시, 사용하지 않은 기간에 대한 환불은 진행되지 않습니다.
# 3     샘플 데이터가 필요하신 고객님들 께서는 고객센터 이메일로 요청 주시면 바로 도와드리...
# 4     당좌비율이란, 안정성 KPI 중 하나 입니다.\n당좌자산을 유동부채로 나눈 값을 말...
# ...                                                 ...
# 3037                      더 자세한 내용은 고객 센터로 문의해주시기 바랍니다.
# 3038  일시적인 현상일 가능성이 높아서 페이지를 새로고침하시는 것을 권장합니다.\n문제가 ...
# 3039                      더 자세한 내용은 고객 센터로 문의해주시기 바랍니다.
# 3040  마케팅 역량 지수에서 시장 가능성의 세부요소로는 '동종 업계 내에서 기업 관련 제품...
# 3041  결제가 가능한 카드는 [신한, BC, KB국민, 현대, 삼성, 롯데, 하나(구외환)...
#
# [3042 rows x 2 columns]

# %%
# df_test = pd.read_csv(f"/content/drive/MyDrive/Colab Notebooks/dataset/prepdata/test_prompt.csv", encoding="utf8")
# df_test = df_test.fillna("none")
# df_test.columns = ["input", "output"]
# df_test["input"] = df_test["input"].astype("str").apply(lambda x: x.strip())
# df_test["output"] = df_test["output"].astype("str").apply(lambda x: x.strip())
# test_prompt = df_test["input"].to_list()
# df_test

# %% [markdown]
# ## Create dataset

# %%
config_tokenizer = {
    "max_length": CFG.max_seq_len,
    "padding": "max_length",
    "truncation": True,
    "return_token_type_ids": False,
    "return_tensors": "pt",
}

# %%
tokenizer = AutoTokenizer.from_pretrained(CFG.model_id, padding_side="right")

if CFG.validation_split:
    shuffled_idx = np_rnd.permutation(len(df_qa))
    feature_container = DatasetDict({
        "train": Dataset.from_pandas(df_qa.iloc[shuffled_idx[int(len(df_qa) * CFG.validation_ratio):]]).with_format("torch"),
        "valid": Dataset.from_pandas(df_qa.iloc[shuffled_idx[:int(len(df_qa) * CFG.validation_ratio)]]).with_format("torch"),
    })
else:
    feature_container = DatasetDict({
        "train": Dataset.from_pandas(df_qa).with_format("torch"),
    })

feature_container = feature_container.map(lambda x: {'text': f"### 질문: {x['input']}\n\n### 답변: {x['output']}<|endoftext|>"}, remove_columns=feature_container["train"].column_names)
feature_container = feature_container.map(lambda samples: tokenizer(samples["text"], **config_tokenizer), remove_columns=feature_container["train"].column_names)
feature_container = feature_container.map(lambda samples: {"input_ids": samples["input_ids"].squeeze(dim=0), "attention_mask": samples["attention_mask"].squeeze(dim=0)})

display(feature_container["train"])
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/210 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# Map:   0%|          | 0/3042 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3042 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3042 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 3042
# })

# %%
tokenizer = AutoTokenizer.from_pretrained(CFG.model_id, padding_side="left")

df_test = pd.read_csv(f"/content/drive/MyDrive/Colab Notebooks/dataset/prepdata/test_prompt.csv", encoding="utf8")
# df_test = df_test.iloc[[28, 39, 59, 2, 44]].reset_index(drop=True)
df_test = df_test.fillna("none")
df_test.columns = ["input", "output"]
df_test["input"] = df_test["input"].astype("str").apply(lambda x: x.strip())
df_test["output"] = df_test["output"].astype("str").apply(lambda x: x.strip())
test_prompt = df_test["input"].to_list()
display(df_test)

test_ds = DatasetDict({
    "test": Dataset.from_pandas(df_test).with_format("torch"),
})

test_ds = test_ds.map(lambda x: {'text': f"### 질문: {x['input']}\n\n### 답변:"}, remove_columns=test_ds["test"].column_names)
test_ds = test_ds.map(lambda samples: tokenizer(samples["text"], **config_tokenizer), remove_columns=test_ds["test"].column_names)
test_ds = test_ds.map(lambda samples: {"input_ids": samples["input_ids"].squeeze(dim=0), "attention_mask": samples["attention_mask"].squeeze(dim=0)})

display(test_ds["test"])
# Out:
#                                                 input  \
# 0                        세금계산서 신청 후 내역은 어떻게 알 수 있을까요?
# 1                            세금계산서 신청을 했는데 이메일이 안왔어요.
# 2                             업종을 선택했는데 통계정보 표시가 안돼요.
# 3                              PDF 버튼을 클릭했는데 저장이 안돼요.
# 4                            동종업계 분석 결과 리스트를 알 수 있나요?
# 5                          외국인도 FNCSP 서비스를 이용할 수 있나요?
# 6                                      컨설턴트 구독이란 뭐에요?
# 7                           일반 가입하고 컨설턴트 구독하고 뭐가 달라요?
# 8                   가장 높거나 낮은 평가지수를 가진 업종을 선택할 순 없나요?
# 9                                 전체 업종별 통계를 볼 수 있나요?
# 10                                           기업 선택 오류
# 11                                       PDF 저장 버튼 오류
# 12                                      조회불가 표시 조치 방법
# 13                                산업통계정보에서 조회불가로 뜹니다.
# 14                            평가점수가 안 보이는데 어떻게 조치하나요?
# 15                                      평가점수 안 보이는 현상
# 16              조희가 안 되는 기업은 어떻게 해요? 기업 등록을 요청하고 싶어요.
# 17                                   검색 안 되는 기업 등록 요청
# 18  검색에 관련 유통사나 대리점이 너무 많이 나와서 원하는 회사가 나오지 않을땐 어떻게...
# 19                내가 원하는 기업이 안나오고 필요없는 기업이 너무 많이 나와요.
# 20          6대 역량 기반으로 필터링을 해서 검색하고 싶은데, 세부검색기능이 없나요?
# 21                          대분류나 중분류 말고 세부검색 기능은 없나요?
# 22                                          즐겨찾기 없나요?
# 23                          매번 검색 말고 자주찾는기업같은 기능 없나요?
# 24                              6대 역량지수를 정리한 자료는 없나요?
# 25                                 역량지수를 정리한 자료는 없나요?
# 26                              FNCSP 홈페이지를 더 알고 싶어요.
# 27                                 더 많은 FNCSP 홈페이지 정보
# 28                          아이디와 비밀번호가 정확한데 로그인이 안돼요.
# 29                                          일반회원 가입방법
# 30                                          기업회원 가입방법
# 31                       가입하지 않고 데이터몰 상품을 결제할 수 있을까요?
# 32                         신용카드 결제 시, 결제창이 나타나지 않습니다.
# 33                          산업 분류체계는 어떤 기준으로 만들어져있나요?
# 34                            아이디랑 비번 맞는데 로그인이 왜 안되죠?
# 35                                   일반회원으로 어떻게 가입해요?
# 36                            기업회원으로 가입하려면 어떻게 해야 해요?
# 37                      데이터몰 상품을 가입하지 않고도 결제할 수 있을까요?
# 38                   조회기능을 클릭했는데 산업통계정보 페이지로 이동이 안돼요.
# 39                              기업컨설팅보고서 구성이 어떻게 되나요?
# 40                           조회를 클릭했는데 페이지로 이동이 안됩니다.
# 41                                  컨설턴트 전환은 어떻게 하나요?
# 42                                      당기순이익이 무엇인가요?
# 43                                     영업이익률이란 무엇인가요?
# 44                                       당좌비율이 무엇인가요?
# 45                      평판 정보 지수에서 일반평판의 세부요인은 무엇인가요?
# 46  평판 정보 지수의 일반평판에서 온라인 커뮤니티 내 기업 관련 감성 강도 평가 수준은...
# 47  평판 정보 지수의 일반평판에서 취업 정보 커뮤니티 내 기업 관련 평가 수준은 어떻게...
# 48                                           수익성 구성요인
# 49                                         신용 지수 구성요인
# 50                      등록된 기업들의 업종 분류는 어떤 식으로 이뤄졌나요?
# 51                                      왜 업데이트가 안 돼죠?
# 52                   데이터 몰에서 데이터의 이용요금은 어떤 식으로 산정됐나요?
# 53                        FNCSP는 어떤 서비스를 제공하는 플랫폼인가요?
# 54                                 데이터 이용요금이 너무 부담돼요.
# 55            데이터 몰에서 구매한 데이터의 갱신주기가 지나면 다시 결제해야 하나요?
# 56                기업성장지수의 기업 등급과 종합점수는 어떤 식으로 산출 되나요?
# 57                              챗봇이 제공한 링크로 연결되지 않아요.
# 58                         일반회원과 컨설턴트 회원의 차이점은 무엇인가요?
# 59                                  FNCSP의 핵심기능을 알려줘.
#
#                                                output
# 0                  빠른 처리를 위해 고객센터로 연락주시면 바로 도와드리겠습니다.
# 1                  빠른 처리를 위해 고객센터로 연락주시면 바로 도와드리겠습니다.
# 2              일시적인 현상일 가능성이 높기 때문에 페이지 새로고침을 권장드립니다.
# 3   일시적인 현상일 가능성이 높기 때문에 페이지 새로고침을 권장드립니다.\n문제가 해결...
# 4                             자세한 내용은 고객 센터로 문의 바랍니다.
# 5                             자세한 내용은 고객 센터로 문의 바랍니다.
# 6                                자세한 건 고객센터에 물어봐 주세요.
# 7                                자세한 건 고객센터에 물어봐 주세요.
# 8                             네, 현재 지원되지 않고 있는 기능입니다.
# 9                           아니요, 현재 지원되지 않고 있는 기능입니다.
# 10  페이지 새로고침 후 다시 시도하세요.\n문제가 해결되지 않는다면 FNCSP 홈페이지...
# 11  페이지 새로고침 후 다시 시도하세요.\n문제가 해결되지 않는다면 FNCSP 홈페이지...
# 12  해당 산업의 데이터가 준비중일 때 조회 불가 표시 됩니다.\n추후의 적재되는 데이터...
# 13  해당 산업의 데이터가 준비중일 때 조회 불가 표시 됩니다.\n추후의 적재되는 데이터...
# 14  해당 업종의 데이터의 양이 충족되지 않아서 평가점수로 표시가 되지 않을때 표시가 되...
# 15  해당 업종의 데이터의 양이 충족되지 않아서 평가점수로 표시가 되지 않을때 표시가 되...
# 16                             해당 부분은 고객 센터로 문의 바랍니다.
# 17                             해당 부분은 고객 센터로 문의 바랍니다.
# 18  그러하실 경우 예로 '삼성전자'와 같이 검색하시기 보다는 '(주)삼성전자'와 같이 ...
# 19  그러하실 경우 예로 '삼성전자'와 같이 검색하시기 보다는 '(주)삼성전자'와 같이 ...
# 20                            네, 현재 지원되고 있지 않은 기능입니다.
# 21                            네, 현재 지원되고 있지 않은 기능입니다.
# 22                            네, 현재 지원되고 있지 않은 기능입니다.
# 23                            네, 현재 지원되고 있지 않은 기능입니다.
# 24  네, 현재 파일로 제공해드리고 있지는 않습니다만 챗봇을 통해 질문주시면 답변드릴 수...
# 25  네, 현재 파일로 제공해드리고 있지는 않습니다만 챗봇을 통해 질문주시면 답변드릴 수...
# 26       추가적으로 FNCSP 홈페이지 아래에 공식 유튜브 채널을 이용해보시기 바랍니다.
# 27  더욱 상세한 정보를 원하신다면, FNCSP 홈페이지 아래에 서비스 소개서 다운로드를...
# 28  아이디와 비밀번호 찾기 링크는 다음과 같으며, 로그아웃 상태에서 찾기가 가능합니다....
# 29  FNCSP 일반회원 가입은 약관 동의 이후 회원가입 화면에서 일반회원을 체크한 뒤 ...
# 30  FNCSP 기업회원 가입은 약관 동의 이후 회원가입 화면에서 컨설턴트회원을 체크한 ...
# 31  FNCSP는 회원가입을 하셔야만 이용이 가능합니다.\n일반 회원으로도 일정 서비스 ...
# 32  PC환경 또는 카드사별 EXE 프로그램이 정상적으로 설치되지 않아 결제 창이 나타나...
# 33  분류기준은 한국 통계청 산업군 분류체계에 기반합니다.\n아래의 웹사이트를 참고해주세...
# 34  아이디나 비밀번호 찾기는 여기서 할 수 있어요.\n그런데, 쿠키 차단 설정 때문에 ...
# 35  FNCSP에 일반회원으로 가입하려면 약관에 동의한 다음, 회원가입 화면에서 '일반회...
# 36  FNCSP에 기업회원으로 가입하려면, 약관 동의한 다음 회원가입 화면에서 '컨설턴트...
# 37  FNCSP는 회원가입을 하셔야만 서비스를 이용하실 수 있어요.\n일반 회원으로도 몇...
# 38  페이지로 이동 했을 때 오류가 발생하면 아래 내용의 해당사항이 있는지 확인해주시기 ...
# 39  유형별로 표시되며\n1. 기업진단컨설팅\n2. 기업진단컨설팅\n3. 경영/재무 전략...
# 40  페이지로 이동 했을 때 오류가 발생하면 아래 내용의 해당사항이 있는지 확인해주시기 ...
# 41  FNCSP 기업회원 가입은 약관 동의 이후 회원가입 화면에서 컨설턴트회원을 체크한 ...
# 42  당기순이익이란, 수익성 KPI 중 하나입니다.\n기업이 일정 기간 동안 얻은 모든 ...
# 43  영업이익률이란, 수익성 KPI 중 하나입니다.\n매출액 대비 영업이익의 비율을 의미...
# 44  당좌비율이란, 안정성 KPI 중 하나 입니다.\n당좌자산을 유동부채로 나눈 값을 말...
# 45  평판 정보 지수에서 일반평판의 세부요인으로는 ['온라인 커뮤니티 내 기업 관련 감성...
# 46  평판 정보 지수의 일반평판에서 온라인 커뮤니티 내 기업 관련 감성 강도 평가 수준은...
# 47  평판 정보 지수의 일반평판에서 취업 정보 커뮤니티 내 기업 관련 평가 수준은 취업 ...
# 48                                            매출영업이익률
# 49                                    [안정성, 성장성, 수익성]
# 50                                               none
# 51                                               none
# 52                                               none
# 53                                               none
# 54                                               none
# 55                                               none
# 56                                               none
# 57                                               none
# 58                                               none
# 59                                               none
# Map:   0%|          | 0/60 [00:00<?, ? examples/s]
# Map:   0%|          | 0/60 [00:00<?, ? examples/s]
# Map:   0%|          | 0/60 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 60
# })

# %% [markdown]
# ## Define helper functions

# %%
def get_optimizer_params(model, eta, weight_decay):
    no_decay = ["bias", "LayerNorm.bias", "LayerNorm.weight"]
    optimizer_parameters = [
        # apply weight decay
        {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
         'lr': eta, 'weight_decay': weight_decay},
        # don't apply weight decay for LayerNormalization layer
        {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
         'lr': eta, 'weight_decay': 0.0},
    ]
    return optimizer_parameters

def get_scheduler(optimizer, num_warmup_steps, num_training_steps):
    scheduler = get_polynomial_decay_schedule_with_warmup(
        optimizer, num_warmup_steps=num_warmup_steps, num_training_steps=num_training_steps, power=0.5, lr_end=1e-5
    )
    return scheduler

# %%
def do_training(params, feature_container, save_path="./tmp/"):
    start_time = time()

    # config on lora for fine-tuning
    lora_config = LoraConfig(
        **params["config_lora"],
        target_modules=["query_key_value"],
        bias="none",
        task_type="CAUSAL_LM"
    )

    # initialize model with quantization
    model = AutoModelForCausalLM.from_pretrained(CFG.model_id, quantization_config=bnb_config)
    model = prepare_model_for_kbit_training(model)
    model.gradient_checkpointing_enable()

    # get model for fine-tuning with lora
    model = get_peft_model(model, lora_config)
    params_info = get_trainable_parameters(model)
    print(params_info)

    # config on training
    if CFG.validation_split:
        train_args = transformers.TrainingArguments(
            num_train_epochs=CFG.epochs,
            per_device_train_batch_size=CFG.batch_size,
            per_device_eval_batch_size=CFG.batch_size,
            gradient_accumulation_steps=1,
            do_eval=True,
            save_strategy="epoch",
            evaluation_strategy="epoch",
            metric_for_best_model="eval_loss",
            load_best_model_at_end=True,
            logging_steps=len(feature_container["train"])//CFG.batch_size,
            output_dir="outputs",
            seed=GLOBAL_SEED,
        )
    else:
        train_args = transformers.TrainingArguments(
            num_train_epochs=CFG.epochs,
            per_device_train_batch_size=CFG.batch_size,
            gradient_accumulation_steps=1,
            do_eval=False,
            logging_steps=len(feature_container["train"])//CFG.batch_size,
            output_dir="outputs",
            seed=GLOBAL_SEED,
        )

    # config optimizer & scheduler
    optimizer_parameters = get_optimizer_params(
        model,
        eta=CFG.eta,
        weight_decay=CFG.weight_decay
    )
    optimizer = AdamW(optimizer_parameters, lr=CFG.eta, weight_decay=CFG.weight_decay)
    scheduler = get_scheduler(
        optimizer,
        num_warmup_steps=0,
        num_training_steps=np.ceil(len(feature_container["train"]) / CFG.batch_size) * CFG.epochs,
    )

    # needed for gpt-neo-x tokenizer
    tokenizer.pad_token = tokenizer.eos_token
    # silence the warnings
    model.config.use_cache = False

    if CFG.validation_split:
        trainer = transformers.Trainer(
            model=model,
            train_dataset=feature_container["train"],
            eval_dataset=feature_container["valid"],
            data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
            optimizers=(optimizer, scheduler),
            args=train_args
        )
    else:
        trainer = transformers.Trainer(
            model=model,
            train_dataset=feature_container["train"],
            data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
            optimizers=(optimizer, scheduler),
            args=train_args
        )

    # training
    training_result = trainer.train()

    # save model
    createFolder(save_path)
    model.save_pretrained(save_path + "model/")
    tokenizer.save_pretrained(save_path + "tokenizer/")

    end_time = time()

    output = {
        "params_info": params_info,
        "training_result": training_result,
        "training_runtime": round(end_time - start_time, 3),
        "training_runtime_per_sample": round((end_time - start_time) / len(feature_container["train"]), 3),
    }

    del model
    gc.collect()
    torch.cuda.empty_cache()
    return output


def do_inference(params, model, prompt):
    start_time = time()

    gen_config = {
        **params,
        "early_stopping": True if params["num_beams"] > 1 else False,
        # "eos_token_id": 2,
        "pad_token_id": tokenizer.eos_token_id,
    }

    # generating
    response= []
    for batch in tqdm(DataLoader(prompt, batch_size=CFG.batch_size//2 if params["num_beams"] > 1 else CFG.batch_size, shuffle=False)):
        for k in batch.keys():
            batch[k] = batch[k].to(device)
        with torch.no_grad():
            gened = model.generate(
                **batch,
                **gen_config,
            )
        response.extend(tokenizer.batch_decode(gened, skip_special_tokens=True))
        del batch, gened
        gc.collect()
        torch.cuda.empty_cache()

    end_time = time()

    # decoding & return
    output = {
        "response": response,
        "inference_runtime": round(end_time - start_time, 3),
        "inference_runtime_per_sample": round((end_time - start_time) / len(prompt), 3),
    }

    return output

# %% [markdown]
# ## Training

# %%
# config on model for quantization
bnb_config = BitsAndBytesConfig(
    # 모델을 4bit로 로딩하도록 설정합니다
    load_in_4bit=True,
    # double quantization 모드를 활성화합니다 (weight 저장과 계산을 다른 타입으로 할 수 있게 합니다)
    bnb_4bit_use_double_quant=True,
    # double quantization 모드에서 저장될 4bit 데이터 타입을 지정합니다
    bnb_4bit_quant_type="nf4",
    # double quantization 모드에서 계산에 사용할 데이터 타입을 지정합니다
    bnb_4bit_compute_dtype=torch.bfloat16,
    # set device
    device_map="auto",
)

training_fixed_params = {}
if CFG.debug:
    training_search_space = {
        "config_lora": {
            "r": [CFG.max_lora_r],
            "lora_alpha": [32],
            "lora_dropout": [1/2**2],
        }
    }
else:
    # training_search_space = {
    #     "config_lora": {
    #         "r": [CFG.max_lora_r, CFG.max_lora_r//2, CFG.max_lora_r//4],
    #         "lora_alpha": [32, 16, 8],
    #         "lora_dropout": [1/2**2, 1/2**3, 1/2**4],
    #     }
    # }
    training_search_space = {
        "config_lora": {
            "r": [CFG.max_lora_r],
            "lora_alpha": [32],
            "lora_dropout": [1/2**4],
        }
    }

# "greedy": {"num_beams": 1, "do_sample": False},
# "multinomial_greedy": {"num_beams": 1, "do_sample": True},
# "beam_search": {"num_beams": 5, "do_sample": False},
# "multinomial_beam_search": {"num_beams": 5, "do_sample": True},
inference_fixed_params = {
    "max_new_tokens": 128,
    "num_beams": 1,
    "early_stopping": False,
    "do_sample": False,
    # "temperature": 0.01,
    # "top_k": 50,
    "use_cache": True,
    "pad_token_id": tokenizer.eos_token_id,
}
if CFG.debug:
    inference_search_space = {
        "generator": {
            "num_beams": [1],
            "do_sample": [False]
        }
    }
else:
    inference_search_space = {
        "generator": {
            "num_beams": [1],
            # do sampling with conditional probability
            "do_sample": [False]
        }
    }


# time_name = datetime.now().strftime('%Y-%m-%d_%H-%M')
time_name = "2023-09-02_08-42"

# %%
pred_output = {}

for idx, value in enumerate(product(*training_search_space["config_lora"].values())):
    seed_everything(GLOBAL_SEED)
    architecture_name = f"kullm_12.8b_{CFG.dataset_version}_{time_name}_case{idx}"
    save_path = f"/content/drive/MyDrive/Colab Notebooks/architecture/{architecture_name}/"
    # createFolder(save_path + "test_case/")
    # params = training_fixed_params.copy()
    # params.update({"config_lora": {k: v for k, v in zip(training_search_space["config_lora"].keys(), value)}})
    # # training
    # output = do_training(params, feature_container, save_path)
    # # save output
    # with open(save_path + "search_params.json", "w", encoding="utf8") as f:
    #     f.write(json.dumps(params))
    # with open(save_path + "training_output.json", "w", encoding="utf8") as f:
    #     f.write(json.dumps(output))

    # load model for inference
    model = AutoModelForCausalLM.from_pretrained(save_path + "model/", quantization_config=bnb_config)
    model.eval()
    model.config.use_cache = True

    for idx2, value2 in enumerate(product(*inference_search_space["generator"].values())):
        response_container = []
        params = inference_fixed_params.copy()
        # params.update({k: v for k, v in zip(inference_search_space["generator"].keys(), value2)})
        # inferenceidx2
        output = do_inference(params, model, test_ds["test"])
        response_container = {"prompt": test_prompt, "response": output["response"]}
        # save output
        # pd.DataFrame(response_container).to_csv(save_path + f"test_case/test_case{idx2}.csv", encoding="utf8", index=False)
        with open(save_path + f"test_case/test_case{idx2}.json", "w", encoding="utf8") as f:
            f.write(json.dumps(response_container))
        with open(save_path + f"test_case/inference_params{idx2}.json", "w", encoding="utf8") as f:
            f.write(json.dumps(params))
        with open(save_path + f"test_case/inference_output{idx2}.json", "w", encoding="utf8") as f:
            f.write(json.dumps({"inference_runtime": output["inference_runtime"], "inference_runtime_per_sample": output["inference_runtime_per_sample"]}))

    del model
    gc.collect()
    torch.cuda.empty_cache()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/714 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/52.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00003.bin:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00003.bin:   0%|          | 0.00/9.93G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00003.bin:   0%|          | 0.00/6.01G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# 100%|██████████| 60/60 [14:56<00:00, 14.94s/it]

# %%
df_qa = pd.read_csv(f"/content/drive/MyDrive/Colab Notebooks/dataset/prepdata/FNCSP_FAQ_전처리_{CFG.dataset_version}.csv", encoding="utf8")
df_qa.columns = ["prompt", "answer"]
df_qa["prompt"] = df_qa["prompt"].astype("str").apply(lambda x: x.strip())
df_qa["answer"] = df_qa["answer"].astype("str").apply(lambda x: x.strip())

# %%
df_pred = pd.DataFrame(response_container)
df_pred["prompt"] = df_pred["prompt"].apply(lambda x: x.strip())

# %%
df_pred = df_pred.merge(df_qa.iloc[:(len(df_qa) // 3)], on="prompt", how="left")

# %%
# df_pred.to_csv(save_path + "test_case/test_pred_all.csv", index=False, encoding="utf8")
