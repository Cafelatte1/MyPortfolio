# %%
import pandas as pd
import numpy as np

# %%
ensemble_list = ["/content/drive/MyDrive/Colab Notebooks/projects/Dacon/plant_leaf_weight_prediction/LB_Archive/LB_0.22494/testResult_knnRandomnormalNA_pretrainedSwin_Dense_v2_try1.csv의 사본",
                 "/content/drive/MyDrive/Colab Notebooks/projects/Dacon/plant_leaf_weight_prediction/LB_Archive/LB_0.24807/testResult_knnRandomnormalNA_pretrainedEffiV2_Dense_v1_try1.csv의 사본",
                 "/content/drive/MyDrive/Colab Notebooks/projects/Dacon/plant_leaf_weight_prediction/LB_Archive/LB_0.25096/testResult_knnRandomnormalNA_pretrainedSwin_LSTM_v1_try1.csv의 사본"]

# %%
tmp_df = pd.concat([pd.read_csv(i)[["leaf_weight"]] for i in ensemble_list], axis=1)

# %%
tmp_df.head()
# Out:
#    leaf_weight  leaf_weight  leaf_weight
# 0    63.650168    51.757078    70.782263
# 1   286.545063   253.612034   281.268738
# 2     6.423873     7.695691     6.192341
# 3    80.806639    70.062510    84.814638
# 4    77.784974    82.448416    81.782327

# %%
submission = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/projects/Dacon/plant_leaf_weight_prediction/train_test_set/sample_submission.csv")

# %%
submission["leaf_weight"] = tmp_df.mean(axis=1).values

# %%
submission.head()
# Out:
#   img_name  leaf_weight
# 0  001.png    62.063170
# 1  002.png   273.808612
# 2  003.png     6.770635
# 3  004.png    78.561262
# 4  005.png    80.671906

# %%
submission.to_csv("/content/drive/MyDrive/Colab Notebooks/projects/Dacon/plant_leaf_weight_prediction/architectures/ensemble_v1/submission.csv", index=False)
